# %% [markdown]
# <a href="https://colab.research.google.com/github/IsagiYoichi640/data-science-4/blob/main/Data_Science_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
a=np.array([9,21,89,78,34,54,75,23,65,34])
plt.hist(a)
plt.show()
